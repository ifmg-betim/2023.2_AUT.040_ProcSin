# %%
# Importa bibliotecas
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import IPython.display as ipd
from scipy.io import wavfile
from scipy import signal
# para figuras estáticas, use:
# %matplotlib inline
# OU, para figuras interativas, use:
# %matplotlib widget

# %%
# lê arquivo de áudio
fs, data = wavfile.read('hallelujah.wav')
data = (data-np.mean(data))/255
tempo = np.arange(len(data))/fs*1000

# player para o arquivo original
aleluia = data
ipd.Audio(aleluia, rate=fs, normalize=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(8,1.5))
plt.plot(data)
plt.plot(data[::-1])
plt.xlabel("tempo [ms]")
# plt.xlim((0,max(tempo)))
plt.show();

# %%
# player para o arquivo original
aleluia = data
ipd.Audio(aleluia, rate=fs, normalize=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# player para o arquivo original
aleluia = data*0.2
ipd.Audio(aleluia, rate=fs, normalize=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# player para o arquivo original
aleluia = data[::2]
ipd.Audio(aleluia, rate=fs, normalize=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# player para o arquivo original
aleluia = data[::3]
ipd.Audio(aleluia, rate=fs, normalize=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# player para o arquivo original
aleluia = data
ipd.Audio(aleluia, rate=2*fs, normalize=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fs
# Out:
# 11025
